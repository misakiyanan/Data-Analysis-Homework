# %%
import pandas as pd
import pymysql

# %%
user_act = pd.read_csv('user_act.csv')
user_act
# Out:
#        user_id      time
# 0     98047837   6/12/19
# 1     97726136   9/12/19
# 2     98607707  18/12/19
# 3     98662432   6/12/19
# 4     98145908  16/12/19
# ...        ...       ...
# 7511   4524349  29/11/19
# 7512  11683492  23/11/19
# 7513  11683492  19/11/19
# 7514   4524349  27/11/19
# 7515  36471333  26/11/19
#
# [7516 rows x 2 columns]

# %%
def date_formatting(date_str):
    d, m, y = date_str.split('/')[0],  date_str.split('/')[1],  date_str.split('/')[2]
    if len(d) == 1:
        d = "0" + d
    if len(m) == 1:
        m = "0" + m
    formatted = '20'+y+'-'+m+'-'+d
    return formatted

# %%
date_formatting('6/7/21')
# Out:
# '2021-07-06'

# %%
user_act['time'] = user_act['time'].apply(date_formatting)

# %%
user_act
# Out:
#        user_id        time
# 0     98047837  2019-12-06
# 1     97726136  2019-12-09
# 2     98607707  2019-12-18
# 3     98662432  2019-12-06
# 4     98145908  2019-12-16
# ...        ...         ...
# 7511   4524349  2019-11-29
# 7512  11683492  2019-11-23
# 7513  11683492  2019-11-19
# 7514   4524349  2019-11-27
# 7515  36471333  2019-11-26
#
# [7516 rows x 2 columns]

# %%
records = user_act.to_records(index=False).tolist()
records  # with datetime format revised
# Out:
# [(98047837, '2019-12-06'),
#  (97726136, '2019-12-09'),
#  (98607707, '2019-12-18'),
#  (98662432, '2019-12-06'),
#  (98145908, '2019-12-16'),
#  (93784494, '2019-12-03'),
#  (94832743, '2019-12-13'),
#  (95290487, '2019-11-27'),
#  (96610296, '2019-12-11'),
#  (100684618, '2019-12-05'),
#  (100509623, '2019-12-08'),
#  (101781721, '2019-12-13'),
#  (103891828, '2019-12-01'),
#  (101260672, '2019-12-12'),
#  (104811265, '2019-12-11'),
#  (103802946, '2019-11-20'),
#  (104221274, '2019-12-14'),
#  (110418606, '2019-12-09'),
#  (100684618, '2019-11-26'),
#  (100509623, '2019-11-21'),
#  (101781721, '2019-12-12'),
#  (103891828, '2019-12-08'),
#  (101260672, '2019-11-28'),
#  (104811265, '2019-12-05'),
#  (103802946, '2019-11-23'),
#  (104221274, '2019-11-29'),
#  (110418606, '2019-11-25'),
#  (100509623, '2019-12-15'),
#  (101781721, '2019-12-16'),
#  (101260672, '2019-12-17'),
#  (104811265, '2019-12-15'),
#  (103802946, '2019-12-18'),
#  (104221274, '2019-12-04'),
# ...

# %%
connect = pymysql.connect(host='localhost', 
                          user='root', 
                          passwd='Chouchou186', 
                          database='homework_20210708')
mycursor = connect.cursor()

for row in records:
    sql = 'INSERT INTO temp_user_act (user_id, dates) VALUES ({0}, "{1}")'.format(row[0], row[1])
    print(sql)
    mycursor.execute(sql)
connect.commit()
# Out:
# INSERT INTO temp_user_act (user_id, dates) VALUES (98047837, "2019-12-06")
# INSERT INTO temp_user_act (user_id, dates) VALUES (97726136, "2019-12-09")
# INSERT INTO temp_user_act (user_id, dates) VALUES (98607707, "2019-12-18")
# INSERT INTO temp_user_act (user_id, dates) VALUES (98662432, "2019-12-06")
# INSERT INTO temp_user_act (user_id, dates) VALUES (98145908, "2019-12-16")
# INSERT INTO temp_user_act (user_id, dates) VALUES (93784494, "2019-12-03")
# INSERT INTO temp_user_act (user_id, dates) VALUES (94832743, "2019-12-13")
# INSERT INTO temp_user_act (user_id, dates) VALUES (95290487, "2019-11-27")
# INSERT INTO temp_user_act (user_id, dates) VALUES (96610296, "2019-12-11")
# INSERT INTO temp_user_act (user_id, dates) VALUES (100684618, "2019-12-05")
# INSERT INTO temp_user_act (user_id, dates) VALUES (100509623, "2019-12-08")
# INSERT INTO temp_user_act (user_id, dates) VALUES (101781721, "2019-12-13")
# ...

# %%
# close
mycursor.close()
connect.close()
